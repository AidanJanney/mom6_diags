# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %matplotlib inline
import warnings
from mom6_tools.section_transports import Transport, options, plotPanel

import matplotlib.pyplot as plt
from mom6_tools.m6toolbox import cime_xmlquery 
import xarray as xr
import yaml, os, numpy

# %%
# Empty class object to pass into Transports (replaced by domain class in the future)

class args:
    pass

# %%
casename = 'CrocCaribGio'
#OUTDIR = '/glade/derecho/scratch/ajanney/archive/CrocCaribGio/ocn/hist/'


## Transport in mom6-tools expects the non-combined files (see notes on mppnccombine)
OUTDIR = '/glade/derecho/scratch/ajanney/CrocCaribGio/run/'

sections = {
    'Barbados': ['umo', None] # Range from diag_table (lon_min,lon_max,lat_min,lat_max-59.613 -59.613 8.177 13.166
    # mom6tools comes with a built in observational estimate feature, but we would adjust this in the future
}

# %%
args.infile = OUTDIR
args.start_date = '2001-01-01'
args.end_date = '2001-01-01'
args.label=''
args.parallel = False
args.debug = False
args.casename = casename

# %%
barbados = Transport(args, sections, 'Barbados', debug = True, opt_id='.2000-01')
# Out:
# ##################################
# Processing  Barbados
# var  umo
# obs  None
# ylim  None
# ##################################
# Full path  /glade/derecho/scratch/ajanney/CrocCaribGio/run/CrocCaribGio.mom6.Barbados.2000-01*
# Tiles  ['0201', '0249', '0217', '0185', '0233']
# Start date 2001-01-01; End date 2001-01-01
# inFileName /glade/derecho/scratch/ajanney/CrocCaribGio/run/CrocCaribGio.mom6.Barbados.2000-01*nc.0201, variable umo
# <string>:45: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
# <xarray.Dataset> Size: 56kB
# Dimensions:      (xh_sub02: 1, yh_sub02: 14, z_l: 39, z_i: 40, time: 5,
#                   nbnd: 2, xq_sub02: 1)
# Coordinates:
#   * xh_sub02     (xh_sub02) float64 8B -59.61
#   * yh_sub02     (yh_sub02) float64 112B 8.759 8.842 8.926 ... 9.674 9.757 9.84
# ...

# %%
ds = xr.open_mfdataset('/glade/derecho/scratch/ajanney/CrocCaribGio/run/CrocCaribGio.mom6.Barbados.2000-01*nc.0201', combine='by_coords')
# Out:
# /glade/derecho/scratch/ajanney/tmp/ipykernel_54065/1729229968.py:1: FutureWarning: In a future version of xarray decode_timedelta will default to False rather than None. To silence this warning, set decode_timedelta to True, False, or a 'CFTimedeltaCoder' instance.
#   ds = xr.open_mfdataset('/glade/derecho/scratch/ajanney/CrocCaribGio/run/CrocCaribGio.mom6.Barbados.2000-01*nc.0201', combine='by_coords')
